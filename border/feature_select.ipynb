# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.ensemble import RandomForestRegressor


data_origin = pd.read_excel("peace agreement.xlsx")
#data = data_origin.loc[ data_origin['NatRes'] == 1 ]
data = data_origin.loc[:,['StInd','StBor','StXbor','NatRes']]
test_data = data.loc[:,['StInd','StBor','StXbor']]
test_data_Nat = data.loc[:,'NatRes']

test_data.head()
# Out:
#    StInd  StBor  StXbor
# 0      0      0       0
# 1      0      0       0
# 2      0      0       0
# 3      0      0       1
# 4      0      0       0

# %%
model = RandomForestRegressor(random_state=1)
model.fit(test_data, test_data_Nat)

importances = model.feature_importances_
indices = np.argsort(-importances[:])

print(indices)
# Out:
# [1 2 0]

# %%
plt.title('feature selection')
plt.barh(range(len(indices)), importances[indices], color='pink', align='center')
plt.yticks(range(len(indices)), [test_data.columns[i] for i in indices])
plt.xlabel('Relative importance of indicators')
plt.show()
