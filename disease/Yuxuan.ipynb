# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./peace agreement.csv')
df = df.iloc[:,:266]

# %%
cross_table = pd.pivot_table(df , index = ['Reg'], columns = ['NatRes'], values = ['Con'], aggfunc = len)

# %%
group_df = df.groupby(['Con'])['NatRes'].sum().sort_values(ascending=False).head(10) # Top 10
group_df.plot(kind = 'barh')
plt.xlabel('Freq')
plt.show()
