# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./peace agreement.csv')
df = df.iloc[:,:266]

# %%
cross_table = pd.pivot_table(df , index = ['Reg'], columns = ['NatRes'], values = ['Con'], aggfunc = len)

# %%
data = pd.read_csv('./2012-09-01-2012-09-30-Middle_Africa-Northern_Africa.csv')

# %%
cross_table = pd.pivot_table(data , index = ['event_type'], columns = ['location'],
                            values = ['data_id'], aggfunc = len, fill_value = 0)

cross_table = cross_table.T

# %%
data = pd.read_csv('./2004-12-01-2004-12-31-Middle_Africa-Northern_Africa(1).csv')
event_type_freq = data['event_type'].value_counts()
plt.figure(figsize = (6,6))
plt.pie(event_type_freq, labels = event_type_freq.index , autopct='%1.1f%%')
plt.show()

# %%
event_type_freq = data['event_type'].value_counts()
plt.figure(figsize = (6,6))
plt.pie(event_type_freq, labels = event_type_freq.index , autopct='%1.1f%%')
plt.show()
