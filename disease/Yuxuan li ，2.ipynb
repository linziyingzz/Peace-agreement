# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./peace agreement.csv')
df = df.iloc[:,:266]

# %%
cross_table = pd.pivot_table(df , index = ['Reg'], columns = ['NatRes'], values = ['Con'], aggfunc = len)

# %%
df['year_month'] = df['Dat'].apply(lambda x : x[:7])
Dat_NatRes = df.groupby(['year_month'])['NatRes'].sum()
Dat_NatRes.index = pd.to_datetime(Dat_NatRes.index)
plt.figure(figsize = (12,4))
Dat_NatRes.plot()
