# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./peace agreement.csv')
df = df.iloc[:,:266]

# %% [markdown]
# # Step 1 Look for the proportion of natural resource conflicts in various regions.

# %%
cross_table = pd.pivot_table(df , index = ['Reg'], columns = ['NatRes'], values = ['Con'], aggfunc = len)

# %%
fig, axs = plt.subplots(2, 3, figsize = (12,8))
k = 0
for i in range(2):
    for j in range(3):K
        axs[i,j].pie(cross_table.values[k], labels = ['False','True'] , autopct='%1.1f%%' )
        #Keep only one decimal place.False=Other conflicts，True=natural resource conflicts
        axs[i,j].set_title(cross_table.index[k])
        k += 1
